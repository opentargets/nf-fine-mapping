# %% [markdown]
# # LD subset test
#
# This notebook tests the code for subsetting the LD matrix

# %%
import pandas as pd

# %%
data = pd.read_csv("../../testdata/ld_reference.tsv", sep="\t")

# %%
data
# Out:
#   ancestry                                           ldMatrix  \
# 0      AFR  gs://gcp-public-data--gnomad/release/2.1.1/ld/...
# 1      AMR  gs://gcp-public-data--gnomad/release/2.1.1/ld/...
# 2      EAS  gs://gcp-public-data--gnomad/release/2.1.1/ld/...
# 3      FIN  gs://gcp-public-data--gnomad/release/2.1.1/ld/...
# 4      NFE  gs://gcp-public-data--gnomad/release/2.1.1/ld/...
#
#                                              ldIndex
# 0  gs://gcp-public-data--gnomad/release/2.1.1/ld/...
# 1  gs://gcp-public-data--gnomad/release/2.1.1/ld/...
# 2  gs://gcp-public-data--gnomad/release/2.1.1/ld/...
# 3  gs://gcp-public-data--gnomad/release/2.1.1/ld/...
# 4  gs://gcp-public-data--gnomad/release/2.1.1/ld/...

# %%
from pyspark.sql import SparkSession
import hail as hl
from pathlib import Path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 from pyspark.sql import SparkSession
# ----> 2 import hail as hl
#       3 from pathlib import Path
#
# ModuleNotFoundError: No module named 'hail'
